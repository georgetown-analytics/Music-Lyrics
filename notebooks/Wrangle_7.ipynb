# %% [markdown]
# First look at all 2nd wave csvs

# %%
import pandas as pd
import numpy as np
import s3fs
import os
import io
import boto3

import s3fs
fs = s3fs.S3FileSystem(anon=False,key='#####',secret='#####
from dotenv import load_dotenv
load_dotenv(verbose=True)

def aws_session(region_name='us-east-1'):
    return boto3.session.Session(aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'), #looks for any .env file
                                aws_secret_access_key=os.getenv('AWS_ACCESS_KEY_SECRET'), #Has to be in same directory
                                region_name=region_name) #from above

def make_bucket(name, acl): 
    session = aws_session()
    s3_resource = session.resource('s3')
    return s3_resource.create_bucket(Bucket=name, ACL=acl)

def upload_file_to_bucket(bucket_name, file_path):
    session = aws_session()
    s3_resource = session.resource('s3')
    file_dir, file_name = os.path.split(file_path)

    bucket = s3_resource.Bucket(bucket_name)
    bucket.upload_file(
      Filename=file_path,
      Key=file_name,
      ExtraArgs={'ACL': 'public-read'}
    )

    s3_url = f"https://{bucket_name}.s3.amazonaws.com/{file_name}"
    return s3_url

def download_file_from_bucket(bucket_name, s3_key, dst_path):
    session = aws_session()
    s3_resource = session.resource('s3')
    bucket = s3_resource.Bucket(bucket_name)
    bucket.download_file(Key=s3_key, Filename=dst_path)

## download_file_from_bucket('music-demo-lyrics', 'lyrics_25k.csv', 'short_name.csv')
## with open('short_name.csv') as fo:
    ## print(fo.read())

# %%
genre_df = pd.read_csv('s3://music-lyrics/merged2_genre_df.csv')
decades_df = pd.read_csv('s3://music-lyrics/decades3_df.csv')
decades_df(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6b6efe0468e4> in <module>
#       1 genre_df = pd.read_csv('s3://music-lyrics/merged2_genre_df.csv')
#       2 decades_df = pd.read_csv('s3://music-lyrics/decades3_df.csv')
# ----> 3 decades_df(5)
#
# TypeError: 'DataFrame' object is not callable

# %%
genre_df
# Out:
#        original_csv       artist_name                            song_name  \
# 0        genres_csv   /10000-maniacs/                       More Than This
# 1        genres_csv   /10000-maniacs/                       More Than This
# 2        genres_csv   /10000-maniacs/                    Because The Night
# 3        genres_csv   /10000-maniacs/                    Because The Night
# 4        genres_csv   /10000-maniacs/                       These Are Days
# ...             ...               ...                                  ...
# 124225   genres_csv           /sambo/                              Valerie
# 124226   genres_csv           /sambo/                           Wake Me Up
# 124227   genres_csv           /sambo/                           Wake Me Up
# 124228   genres_csv       /seu-jorge/                                Don't
# 124229   genres_csv  /zeca-pagodinho/  Deixa A Vida Me Levar (translation)
#
#                                                      link  \
# 0                      /10000-maniacs/more-than-this.html
# 1                      /10000-maniacs/more-than-this.html
# 2                   /10000-maniacs/because-the-night.html
# 3                   /10000-maniacs/because-the-night.html
# 4                      /10000-maniacs/these-are-days.html
# ...                                                   ...
# 124225                                /sambo/valerie.html
# 124226                             /sambo/wake-me-up.html
# 124227                             /sambo/wake-me-up.html
# 124228                               /seu-jorge/dont.html
# 124229  /zeca-pagodinho/deixa-a-vida-me-levar-translat...
#
#                                                    lyrics language  genre
# 0       I could feel at the time. There was no way of ...  ENGLISH   Rock
# 1       I could feel at the time. There was no way of ...  ENGLISH    Pop
# 2       Take me now, baby, here as I am. Hold me close...  ENGLISH   Rock
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH    Pop
# 4       These are. These are days you'll remember. Nev...  ENGLISH   Rock
# ...                                                   ...      ...    ...
# 124225  Well sometimes I go out by myself. And I look ...  ENGLISH   Rock
# 124226  Feeling my way through the darkness. Guided by...  ENGLISH  Samba
# 124227  Feeling my way through the darkness. Guided by...  ENGLISH   Rock
# 124228  Don't, don't, that's what you say. Each time t...  ENGLISH  Samba
# 124229  I've been. For almost everything in life. In t...  ENGLISH  Samba
#
# [124230 rows x 7 columns]

# %%
decades_df
# Out:
#       original_csv           artist_name                      song_name  link  \
# 0      decades_tcc                mukesh           mohabbat bhi jhoothi   NaN
# 1      decades_tcc         frankie laine                      i believe   NaN
# 2      decades_tcc           johnnie ray                            cry   NaN
# 3      decades_tcc           pérez prado                       patricia   NaN
# 4      decades_tcc  giorgos papadopoulos             apopse eida oneiro   NaN
# ...            ...                   ...                            ...   ...
# 28367  decades_tcc               mack 10                10 million ways   NaN
# 28368  decades_tcc                m.o.p.  ante up (robbin hoodz theory)   NaN
# 28369  decades_tcc                  nine                  whutcha want?   NaN
# 28370  decades_tcc            will smith                         switch   NaN
# 28371  decades_tcc                 jeezy                         r.i.p.   NaN
#
#                                                   lyrics  language    genre  \
# 0      hold time feel break feel untrue convince spea...       NaN      pop
# 1      believe drop rain fall grow believe darkest ni...       NaN      pop
# 2      sweetheart send letter goodbye secret feel bet...       NaN      pop
# 3      kiss lips want stroll charm mambo chacha merin...       NaN      pop
# 4      till darling till matter know till dream live ...       NaN      pop
# ...                                                  ...       ...      ...
# 28367  cause fuck leave scar tick tock clock come kno...       NaN  hip hop
# 28368  minks things chain ring braclets yap fame come...       NaN  hip hop
# 28369  get ban get ban stick crack relax plan attack ...       NaN  hip hop
# 28370  check check yeah yeah hear thing call switch g...       NaN  hip hop
# 28371  remix killer alive remix thriller trap bitch s...       NaN  hip hop
#
#        date
# 0      1950
# 1      1950
# 2      1950
# 3      1950
# 4      1950
# ...     ...
# 28367  2019
# 28368  2019
# 28369  2019
# 28370  2019
# 28371  2019
#
# [28372 rows x 8 columns]

# %%
b

# %%
big_df['artist_name'].replace('(/)','',regex=True, inplace = True) 
big_df
# Out:
#        original_csv    artist_name                      song_name  \
# 0        genres_csv  10000-maniacs                 More Than This
# 1        genres_csv  10000-maniacs                 More Than This
# 2        genres_csv  10000-maniacs              Because The Night
# 3        genres_csv  10000-maniacs              Because The Night
# 4        genres_csv  10000-maniacs                 These Are Days
# ...             ...            ...                            ...
# 152597  decades_tcc        mack 10                10 million ways
# 152598  decades_tcc         m.o.p.  ante up (robbin hoodz theory)
# 152599  decades_tcc           nine                  whutcha want?
# 152600  decades_tcc     will smith                         switch
# 152601  decades_tcc          jeezy                         r.i.p.
#
#                                          link  \
# 0          /10000-maniacs/more-than-this.html
# 1          /10000-maniacs/more-than-this.html
# 2       /10000-maniacs/because-the-night.html
# 3       /10000-maniacs/because-the-night.html
# 4          /10000-maniacs/these-are-days.html
# ...                                       ...
# 152597                                    NaN
# 152598                                    NaN
# 152599                                    NaN
# 152600                                    NaN
# 152601                                    NaN
#
#                                                    lyrics language    genre  \
# 0       I could feel at the time. There was no way of ...  ENGLISH     Rock
# 1       I could feel at the time. There was no way of ...  ENGLISH      Pop
# 2       Take me now, baby, here as I am. Hold me close...  ENGLISH     Rock
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH      Pop
# 4       These are. These are days you'll remember. Nev...  ENGLISH     Rock
# ...                                                   ...      ...      ...
# 152597  cause fuck leave scar tick tock clock come kno...      NaN  hip hop
# 152598  minks things chain ring braclets yap fame come...      NaN  hip hop
# 152599  get ban get ban stick crack relax plan attack ...      NaN  hip hop
# 152600  check check yeah yeah hear thing call switch g...      NaN  hip hop
# 152601  remix killer alive remix thriller trap bitch s...      NaN  hip hop
#
#           date
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 152597  2019.0
# 152598  2019.0
# 152599  2019.0
# 152600  2019.0
# 152601  2019.0
#
# [152602 rows x 8 columns]

# %%
big_df
# Out:
#        original_csv      artist_name                      song_name  \
# 0        genres_csv  /10000-maniacs/                 More Than This
# 1        genres_csv  /10000-maniacs/                 More Than This
# 2        genres_csv  /10000-maniacs/              Because The Night
# 3        genres_csv  /10000-maniacs/              Because The Night
# 4        genres_csv  /10000-maniacs/                 These Are Days
# ...             ...              ...                            ...
# 152597  decades_tcc          mack 10                10 million ways
# 152598  decades_tcc           m.o.p.  ante up (robbin hoodz theory)
# 152599  decades_tcc             nine                  whutcha want?
# 152600  decades_tcc       will smith                         switch
# 152601  decades_tcc            jeezy                         r.i.p.
#
#                                          link  \
# 0          /10000-maniacs/more-than-this.html
# 1          /10000-maniacs/more-than-this.html
# 2       /10000-maniacs/because-the-night.html
# 3       /10000-maniacs/because-the-night.html
# 4          /10000-maniacs/these-are-days.html
# ...                                       ...
# 152597                                    NaN
# 152598                                    NaN
# 152599                                    NaN
# 152600                                    NaN
# 152601                                    NaN
#
#                                                    lyrics language    genre  \
# 0       I could feel at the time. There was no way of ...  ENGLISH     Rock
# 1       I could feel at the time. There was no way of ...  ENGLISH      Pop
# 2       Take me now, baby, here as I am. Hold me close...  ENGLISH     Rock
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH      Pop
# 4       These are. These are days you'll remember. Nev...  ENGLISH     Rock
# ...                                                   ...      ...      ...
# 152597  cause fuck leave scar tick tock clock come kno...      NaN  hip hop
# 152598  minks things chain ring braclets yap fame come...      NaN  hip hop
# 152599  get ban get ban stick crack relax plan attack ...      NaN  hip hop
# 152600  check check yeah yeah hear thing call switch g...      NaN  hip hop
# 152601  remix killer alive remix thriller trap bitch s...      NaN  hip hop
#
#           date
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 152597  2019.0
# 152598  2019.0
# 152599  2019.0
# 152600  2019.0
# 152601  2019.0
#
# [152602 rows x 8 columns]

# %%
big_df.describe(include='all')
# Out:
#        original_csv  artist_name song_name            link  \
# count        152602       152602    152602          124230
# unique            2         6445     90916           87151
# top      genres_csv  chris-brown     Intro  /m-i-a/10.html
# freq         124230         2348        66              12
# mean            NaN          NaN       NaN             NaN
# std             NaN          NaN       NaN             NaN
# min             NaN          NaN       NaN             NaN
# 25%             NaN          NaN       NaN             NaN
# 50%             NaN          NaN       NaN             NaN
# 75%             NaN          NaN       NaN             NaN
# max             NaN          NaN       NaN             NaN
#
#                                   lyrics language   genre          date
# count                             152602   124230  152602  28372.000000
# unique                            114791        1      13           NaN
# top     [This song is an instrumental.].  ENGLISH    Rock           NaN
# freq                                  17   124230   60585           NaN
# mean                                 NaN      NaN     NaN   1990.236888
# std                                  NaN      NaN     NaN     18.487463
# min                                  NaN      NaN     NaN   1950.000000
# 25%                                  NaN      NaN     NaN   1975.000000
# 50%                                  NaN      NaN     NaN   1991.000000
# 75%                                  NaN      NaN     NaN   2007.000000
# max                                  NaN      NaN     NaN   2019.000000

# %%
big_df[big_df.duplicated(subset=['artist_name','song_name'])]
# Out:
#        original_csv    artist_name                song_name  \
# 1        genres_csv  10000-maniacs           More Than This
# 3        genres_csv  10000-maniacs        Because The Night
# 5        genres_csv  10000-maniacs           These Are Days
# 7        genres_csv  10000-maniacs          A Campfire Song
# 9        genres_csv  10000-maniacs  Everyday Is Like Sunday
# ...             ...            ...                      ...
# 124223   genres_csv          sambo                This Love
# 124225   genres_csv          sambo                  Valerie
# 124227   genres_csv          sambo               Wake Me Up
# 126545  decades_tcc        blondie                    11:59
# 148309  decades_tcc          queen                      '39
#
#                                                link  \
# 1                /10000-maniacs/more-than-this.html
# 3             /10000-maniacs/because-the-night.html
# 5                /10000-maniacs/these-are-days.html
# 7               /10000-maniacs/a-campfire-song.html
# 9       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 124223                        /sambo/this-love.html
# 124225                          /sambo/valerie.html
# 124227                       /sambo/wake-me-up.html
# 126545                                          NaN
# 148309                                          NaN
#
#                                                    lyrics language genre  \
# 1       I could feel at the time. There was no way of ...  ENGLISH   Pop
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH   Pop
# 5       These are. These are days you'll remember. Nev...  ENGLISH   Pop
# 7       A lie to say, "O my mountain has coal veins an...  ENGLISH   Pop
# 9       Trudging slowly over wet sand. Back to the ben...  ENGLISH   Pop
# ...                                                   ...      ...   ...
# 124223  I was so high I did not recognize. The fire bu...  ENGLISH  Rock
# 124225  Well sometimes I go out by myself. And I look ...  ENGLISH  Rock
# 124227  Feeling my way through the darkness. Guided by...  ENGLISH  Rock
# 126545  lean corner like candidate sidewalk social sci...      NaN   pop
# 148309  year assemble volunteer days land ship sail bl...      NaN  rock
#
#           date
# 1          NaN
# 3          NaN
# 5          NaN
# 7          NaN
# 9          NaN
# ...        ...
# 124223     NaN
# 124225     NaN
# 124227     NaN
# 126545  1978.0
# 148309  1975.0
#
# [37073 rows x 8 columns]

# %% [markdown]
# 152K songs.  37K repeats.  That ain't bad...

# %%
big_df[big_df.duplicated(subset=['song_name'])]
# Out:
#        original_csv            artist_name                song_name  \
# 1        genres_csv          10000-maniacs           More Than This
# 3        genres_csv          10000-maniacs        Because The Night
# 5        genres_csv          10000-maniacs           These Are Days
# 7        genres_csv          10000-maniacs          A Campfire Song
# 9        genres_csv          10000-maniacs  Everyday Is Like Sunday
# ...             ...                    ...                      ...
# 152555  decades_tcc  rob base & dj ez rock             it takes two
# 152570  decades_tcc           jaydayoungan                  hop out
# 152577  decades_tcc                aaliyah        more than a woman
# 152581  decades_tcc            kurtis blow               basketball
# 152587  decades_tcc       ghostface killah              iron maiden
#
#                                                link  \
# 1                /10000-maniacs/more-than-this.html
# 3             /10000-maniacs/because-the-night.html
# 5                /10000-maniacs/these-are-days.html
# 7               /10000-maniacs/a-campfire-song.html
# 9       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 152555                                          NaN
# 152570                                          NaN
# 152577                                          NaN
# 152581                                          NaN
# 152587                                          NaN
#
#                                                    lyrics language    genre  \
# 1       I could feel at the time. There was no way of ...  ENGLISH      Pop
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH      Pop
# 5       These are. These are days you'll remember. Nev...  ENGLISH      Pop
# 7       A lie to say, "O my mountain has coal veins an...  ENGLISH      Pop
# 9       Trudging slowly over wet sand. Back to the ben...  ENGLISH      Pop
# ...                                                   ...      ...      ...
# 152555  take thing right take outta sight wanna right ...      NaN  hip hop
# 152570  heroes tryna glock straight work niggas talkin...      NaN  hip hop
# 152577  passion instant sweat bead feel cupid shoot he...      NaN  hip hop
# 152581  chours play basketball basketball play basketb...      NaN  hip hop
# 152587  doin turf punk message smokey smokey smokey mo...      NaN  hip hop
#
#           date
# 1          NaN
# 3          NaN
# 5          NaN
# 7          NaN
# 9          NaN
# ...        ...
# 152555  2019.0
# 152570  2019.0
# 152577  2019.0
# 152581  2019.0
# 152587  2019.0
#
# [61686 rows x 8 columns]

# %% [markdown]
# 61K repeats.  That's bad

# %%
big_df[big_df.duplicated(subset=['artist_name','song_name'])]
# Out:
#        original_csv    artist_name                song_name  \
# 1        genres_csv  10000-maniacs           More Than This
# 3        genres_csv  10000-maniacs        Because The Night
# 5        genres_csv  10000-maniacs           These Are Days
# 7        genres_csv  10000-maniacs          A Campfire Song
# 9        genres_csv  10000-maniacs  Everyday Is Like Sunday
# ...             ...            ...                      ...
# 124223   genres_csv          sambo                This Love
# 124225   genres_csv          sambo                  Valerie
# 124227   genres_csv          sambo               Wake Me Up
# 126545  decades_tcc        blondie                    11:59
# 148309  decades_tcc          queen                      '39
#
#                                                link  \
# 1                /10000-maniacs/more-than-this.html
# 3             /10000-maniacs/because-the-night.html
# 5                /10000-maniacs/these-are-days.html
# 7               /10000-maniacs/a-campfire-song.html
# 9       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 124223                        /sambo/this-love.html
# 124225                          /sambo/valerie.html
# 124227                       /sambo/wake-me-up.html
# 126545                                          NaN
# 148309                                          NaN
#
#                                                    lyrics language genre  \
# 1       I could feel at the time. There was no way of ...  ENGLISH   Pop
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH   Pop
# 5       These are. These are days you'll remember. Nev...  ENGLISH   Pop
# 7       A lie to say, "O my mountain has coal veins an...  ENGLISH   Pop
# 9       Trudging slowly over wet sand. Back to the ben...  ENGLISH   Pop
# ...                                                   ...      ...   ...
# 124223  I was so high I did not recognize. The fire bu...  ENGLISH  Rock
# 124225  Well sometimes I go out by myself. And I look ...  ENGLISH  Rock
# 124227  Feeling my way through the darkness. Guided by...  ENGLISH  Rock
# 126545  lean corner like candidate sidewalk social sci...      NaN   pop
# 148309  year assemble volunteer days land ship sail bl...      NaN  rock
#
#           date
# 1          NaN
# 3          NaN
# 5          NaN
# 7          NaN
# 9          NaN
# ...        ...
# 124223     NaN
# 124225     NaN
# 124227     NaN
# 126545  1978.0
# 148309  1975.0
#
# [37073 rows x 8 columns]

# %%
big_df.drop_duplicates(subset=['artist_name','song_name'], inplace = True)
big_df
# Out:
#        original_csv    artist_name                      song_name  \
# 0        genres_csv  10000-maniacs                 More Than This
# 2        genres_csv  10000-maniacs              Because The Night
# 4        genres_csv  10000-maniacs                 These Are Days
# 6        genres_csv  10000-maniacs                A Campfire Song
# 8        genres_csv  10000-maniacs        Everyday Is Like Sunday
# ...             ...            ...                            ...
# 152597  decades_tcc        mack 10                10 million ways
# 152598  decades_tcc         m.o.p.  ante up (robbin hoodz theory)
# 152599  decades_tcc           nine                  whutcha want?
# 152600  decades_tcc     will smith                         switch
# 152601  decades_tcc          jeezy                         r.i.p.
#
#                                                link  \
# 0                /10000-maniacs/more-than-this.html
# 2             /10000-maniacs/because-the-night.html
# 4                /10000-maniacs/these-are-days.html
# 6               /10000-maniacs/a-campfire-song.html
# 8       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 152597                                          NaN
# 152598                                          NaN
# 152599                                          NaN
# 152600                                          NaN
# 152601                                          NaN
#
#                                                    lyrics language    genre  \
# 0       I could feel at the time. There was no way of ...  ENGLISH     Rock
# 2       Take me now, baby, here as I am. Hold me close...  ENGLISH     Rock
# 4       These are. These are days you'll remember. Nev...  ENGLISH     Rock
# 6       A lie to say, "O my mountain has coal veins an...  ENGLISH     Rock
# 8       Trudging slowly over wet sand. Back to the ben...  ENGLISH     Rock
# ...                                                   ...      ...      ...
# 152597  cause fuck leave scar tick tock clock come kno...      NaN  hip hop
# 152598  minks things chain ring braclets yap fame come...      NaN  hip hop
# 152599  get ban get ban stick crack relax plan attack ...      NaN  hip hop
# 152600  check check yeah yeah hear thing call switch g...      NaN  hip hop
# 152601  remix killer alive remix thriller trap bitch s...      NaN  hip hop
#
#           date
# 0          NaN
# 2          NaN
# 4          NaN
# 6          NaN
# 8          NaN
# ...        ...
# 152597  2019.0
# 152598  2019.0
# 152599  2019.0
# 152600  2019.0
# 152601  2019.0
#
# [115529 rows x 8 columns]

# %%
big_df[big_df.duplicated(subset=['song_name'])]
# Out:
#        original_csv            artist_name          song_name  \
# 284      genres_csv              12-stones         Photograph
# 700      genres_csv          4-non-blondes              Train
# 952      genres_csv                  ac-dc          Love Song
# 1249     genres_csv           adam-lambert            Runaway
# 1307     genres_csv           adam-lambert          What's Up
# ...             ...                    ...                ...
# 152555  decades_tcc  rob base & dj ez rock       it takes two
# 152570  decades_tcc           jaydayoungan            hop out
# 152577  decades_tcc                aaliyah  more than a woman
# 152581  decades_tcc            kurtis blow         basketball
# 152587  decades_tcc       ghostface killah        iron maiden
#
#                                link  \
# 284      /12-stones/photograph.html
# 700       /4-non-blondes/train.html
# 952           /ac-dc/love-song.html
# 1249     /adam-lambert/runaway.html
# 1307    /adam-lambert/whats-up.html
# ...                             ...
# 152555                          NaN
# 152570                          NaN
# 152577                          NaN
# 152581                          NaN
# 152587                          NaN
#
#                                                    lyrics language    genre  \
# 284     Fear falls hard like rain again. Washing over ...  ENGLISH     Rock
# 700     What ya gonna do child. When your thoughts are...  ENGLISH     Rock
# 952     I can tell by the look in your eye. I can tell...  ENGLISH     Rock
# 1249    So. High up. Shouting. Why can’t everybody loo...  ENGLISH      Pop
# 1307    Twenty-five years and my life is still. I'm tr...  ENGLISH      Pop
# ...                                                   ...      ...      ...
# 152555  take thing right take outta sight wanna right ...      NaN  hip hop
# 152570  heroes tryna glock straight work niggas talkin...      NaN  hip hop
# 152577  passion instant sweat bead feel cupid shoot he...      NaN  hip hop
# 152581  chours play basketball basketball play basketb...      NaN  hip hop
# 152587  doin turf punk message smokey smokey smokey mo...      NaN  hip hop
#
#           date
# 284        NaN
# 700        NaN
# 952        NaN
# 1249       NaN
# 1307       NaN
# ...        ...
# 152555  2019.0
# 152570  2019.0
# 152577  2019.0
# 152581  2019.0
# 152587  2019.0
#
# [24613 rows x 8 columns]

# %%
big_df.describe(include='all')
# Out:
#        original_csv    artist_name song_name  \
# count        115529         115529    115529
# unique            2           6445     90916
# top      genres_csv  elvis-presley     Intro
# freq          87159            747        50
# mean            NaN            NaN       NaN
# std             NaN            NaN       NaN
# min             NaN            NaN       NaN
# 25%             NaN            NaN       NaN
# 50%             NaN            NaN       NaN
# 75%             NaN            NaN       NaN
# max             NaN            NaN       NaN
#
#                                                   link  \
# count                                            87159
# unique                                           87148
# top     /bee-gees/our-love-dont-throw-it-all-away.html
# freq                                                 2
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#                                   lyrics language   genre          date
# count                             115529    87159  115529  28370.000000
# unique                            114787        1      13           NaN
# top     [This song is an instrumental.].  ENGLISH    Rock           NaN
# freq                                  16    87159   47637           NaN
# mean                                 NaN      NaN     NaN   1990.237857
# std                                  NaN      NaN     NaN     18.487751
# min                                  NaN      NaN     NaN   1950.000000
# 25%                                  NaN      NaN     NaN   1975.000000
# 50%                                  NaN      NaN     NaN   1991.000000
# 75%                                  NaN      NaN     NaN   2007.000000
# max                                  NaN      NaN     NaN   2019.000000

# %%
big_df.drop_duplicates(subset=['song_name'], inplace = True)
big_df
# Out:
#        original_csv    artist_name                      song_name  \
# 0        genres_csv  10000-maniacs                 More Than This
# 2        genres_csv  10000-maniacs              Because The Night
# 4        genres_csv  10000-maniacs                 These Are Days
# 6        genres_csv  10000-maniacs                A Campfire Song
# 8        genres_csv  10000-maniacs        Everyday Is Like Sunday
# ...             ...            ...                            ...
# 152597  decades_tcc        mack 10                10 million ways
# 152598  decades_tcc         m.o.p.  ante up (robbin hoodz theory)
# 152599  decades_tcc           nine                  whutcha want?
# 152600  decades_tcc     will smith                         switch
# 152601  decades_tcc          jeezy                         r.i.p.
#
#                                                link  \
# 0                /10000-maniacs/more-than-this.html
# 2             /10000-maniacs/because-the-night.html
# 4                /10000-maniacs/these-are-days.html
# 6               /10000-maniacs/a-campfire-song.html
# 8       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 152597                                          NaN
# 152598                                          NaN
# 152599                                          NaN
# 152600                                          NaN
# 152601                                          NaN
#
#                                                    lyrics language    genre  \
# 0       I could feel at the time. There was no way of ...  ENGLISH     Rock
# 2       Take me now, baby, here as I am. Hold me close...  ENGLISH     Rock
# 4       These are. These are days you'll remember. Nev...  ENGLISH     Rock
# 6       A lie to say, "O my mountain has coal veins an...  ENGLISH     Rock
# 8       Trudging slowly over wet sand. Back to the ben...  ENGLISH     Rock
# ...                                                   ...      ...      ...
# 152597  cause fuck leave scar tick tock clock come kno...      NaN  hip hop
# 152598  minks things chain ring braclets yap fame come...      NaN  hip hop
# 152599  get ban get ban stick crack relax plan attack ...      NaN  hip hop
# 152600  check check yeah yeah hear thing call switch g...      NaN  hip hop
# 152601  remix killer alive remix thriller trap bitch s...      NaN  hip hop
#
#           date
# 0          NaN
# 2          NaN
# 4          NaN
# 6          NaN
# 8          NaN
# ...        ...
# 152597  2019.0
# 152598  2019.0
# 152599  2019.0
# 152600  2019.0
# 152601  2019.0
#
# [90916 rows x 8 columns]

# %%
big_df.genre.unique()
# Out:
# array(['Rock', 'Pop', 'Hip Hop', 'Sertanejo', 'Samba', 'Funk Carioca',
#        'pop', 'country', 'blues', 'jazz', 'reggae', 'rock', 'hip hop'],
#       dtype=object)

# %%
big_df.shape
# Out:
# (90916, 8)

# %%
big_df.to_csv('big_df.csv', index = False)
upload_file_to_bucket('music-lyrics','big_df.csv')
# Out:
# 'https://music-lyrics.s3.amazonaws.com/big_df.csv'

# %% [markdown]
# big_df is the culmination of the last four days.  Two datasets aligned, de-duplicated, cleaned (a little), merged and concat'd.

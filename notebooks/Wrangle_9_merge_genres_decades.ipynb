# %%
import pandas as pd
import numpy as np
import s3fs
import os
import io
import boto3

import s3fs
fs = s3fs.S3FileSystem(anon=False,key='####',secret='#####')

from dotenv import load_dotenv
load_dotenv(verbose=True)

def aws_session(region_name='us-east-1'):
    return boto3.session.Session(aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'), #looks for any .env file
                                aws_secret_access_key=os.getenv('AWS_ACCESS_KEY_SECRET'), #Has to be in same directory
                                region_name=region_name) #from above

def make_bucket(name, acl): 
    session = aws_session()
    s3_resource = session.resource('s3')
    return s3_resource.create_bucket(Bucket=name, ACL=acl)

def upload_file_to_bucket(bucket_name, file_path):
    session = aws_session()
    s3_resource = session.resource('s3')
    file_dir, file_name = os.path.split(file_path)

    bucket = s3_resource.Bucket(bucket_name)
    bucket.upload_file(
      Filename=file_path,
      Key=file_name,
      ExtraArgs={'ACL': 'public-read'}
    )

    s3_url = f"https://{bucket_name}.s3.amazonaws.com/{file_name}"
    return s3_url

def download_file_from_bucket(bucket_name, s3_key, dst_path):
    session = aws_session()
    s3_resource = session.resource('s3')
    bucket = s3_resource.Bucket(bucket_name)
    bucket.download_file(Key=s3_key, Filename=dst_path)

## download_file_from_bucket('music-demo-lyrics', 'lyrics_25k.csv', 'short_name.csv')
## with open('short_name.csv') as fo:
    ## print(fo.read())

genre_df = pd.read_csv('s3://wrangled-1/merged3_genre_df.csv')
decades_df = pd.read_csv('s3://wrangled-1/decades_df.csv')

# %%
genre_df.describe(include='all')
# Out:
#        original_csv  artist_name song_name  \
# count         94915        94915     94915
# unique            1         1151     67266
# top      genres_csv  chris-brown     Intro
# freq          94915         1124        55
# mean            NaN          NaN       NaN
# std             NaN          NaN       NaN
# min             NaN          NaN       NaN
# 25%             NaN          NaN       NaN
# 50%             NaN          NaN       NaN
# 75%             NaN          NaN       NaN
# max             NaN          NaN       NaN
#
#                                                      link  \
# count                                               94915
# unique                                              87151
# top     /duran-duran/im-looking-for-cracks-in-the-pave...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   lyrics language  genre  date
# count                              94915    94915  94915   0.0
# unique                             86419        1      6   NaN
# top     [This song is an instrumental.].  ENGLISH   Rock   NaN
# freq                                  16    94915  50160   NaN
# mean                                 NaN      NaN    NaN   NaN
# std                                  NaN      NaN    NaN   NaN
# min                                  NaN      NaN    NaN   NaN
# 25%                                  NaN      NaN    NaN   NaN
# 50%                                  NaN      NaN    NaN   NaN
# 75%                                  NaN      NaN    NaN   NaN
# max                                  NaN      NaN    NaN   NaN

# %%
decades_df.describe(include='all')
# Out:
#        original_csv  artist_name song_name  link  \
# count         28372        28372     28372   0.0
# unique            1         5426     23689   NaN
# top     decades_tcc  johnny cash   tonight   NaN
# freq          28372          190        17   NaN
# mean            NaN          NaN       NaN   NaN
# std             NaN          NaN       NaN   NaN
# min             NaN          NaN       NaN   NaN
# 25%             NaN          NaN       NaN   NaN
# 50%             NaN          NaN       NaN   NaN
# 75%             NaN          NaN       NaN   NaN
# max             NaN          NaN       NaN   NaN
#
#                                                    lyrics  language  genre  \
# count                                               28372       0.0  28372
# unique                                              28372       NaN      7
# top     begin live friend live meet common true know e...       NaN    pop
# freq                                                    1       NaN   7042
# mean                                                  NaN       NaN    NaN
# std                                                   NaN       NaN    NaN
# min                                                   NaN       NaN    NaN
# 25%                                                   NaN       NaN    NaN
# 50%                                                   NaN       NaN    NaN
# 75%                                                   NaN       NaN    NaN
# max                                                   NaN       NaN    NaN
#
#                 date
# count   28372.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     1990.236888
# std        18.487463
# min      1950.000000
# 25%      1975.000000
# 50%      1991.000000
# 75%      2007.000000
# max      2019.000000

# %%
big2_df = pd.concat([genre_df, decades_df]).reset_index(drop = True)
big2_df.describe(include='all')
# Out:
#        original_csv  artist_name song_name  \
# count        123287       123287    123287
# unique            2         6445     90916
# top      genres_csv  chris-brown     Intro
# freq          94915         1124        55
# mean            NaN          NaN       NaN
# std             NaN          NaN       NaN
# min             NaN          NaN       NaN
# 25%             NaN          NaN       NaN
# 50%             NaN          NaN       NaN
# 75%             NaN          NaN       NaN
# max             NaN          NaN       NaN
#
#                                                      link  \
# count                                               94915
# unique                                              87151
# top     /duran-duran/im-looking-for-cracks-in-the-pave...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   lyrics language   genre          date
# count                             123287    94915  123287  28372.000000
# unique                            114791        1      13           NaN
# top     [This song is an instrumental.].  ENGLISH    Rock           NaN
# freq                                  16    94915   50160           NaN
# mean                                 NaN      NaN     NaN   1990.236888
# std                                  NaN      NaN     NaN     18.487463
# min                                  NaN      NaN     NaN   1950.000000
# 25%                                  NaN      NaN     NaN   1975.000000
# 50%                                  NaN      NaN     NaN   1991.000000
# 75%                                  NaN      NaN     NaN   2007.000000
# max                                  NaN      NaN     NaN   2019.000000

# %%
big2_df.tail(20)
# Out:
#        original_csv       artist_name  \
# 123267  decades_tcc           mos def
# 123268  decades_tcc           cassidy
# 123269  decades_tcc   eric b. & rakim
# 123270  decades_tcc            t-pain
# 123271  decades_tcc       $uicideboy$
# 123272  decades_tcc  ghostface killah
# 123273  decades_tcc             q-tip
# 123274  decades_tcc            future
# 123275  decades_tcc       nappy roots
# 123276  decades_tcc            eazy-e
# 123277  decades_tcc             rakim
# 123278  decades_tcc           ja rule
# 123279  decades_tcc     nipsey hussle
# 123280  decades_tcc       nappy roots
# 123281  decades_tcc         the roots
# 123282  decades_tcc           mack 10
# 123283  decades_tcc            m.o.p.
# 123284  decades_tcc              nine
# 123285  decades_tcc        will smith
# 123286  decades_tcc             jeezy
#
#                                                 song_name link  \
# 123267                                  sex, love & money  NaN
# 123268                                       a.m. to p.m.  NaN
# 123269                                       paid in full  NaN
# 123270                 look at her go (feat. chris brown)  NaN
# 123271  you're now tuning into 66.6 fm with dj rapture...  NaN
# 123272                                        iron maiden  NaN
# 123273                                     life is better  NaN
# 123274                                       tony montana  NaN
# 123275                                      blowin' trees  NaN
# 123276                                        eazy-duz-it  NaN
# 123277                                when i b on tha mic  NaN
# 123278                                       kill 'em all  NaN
# 123279                                hussle in the house  NaN
# 123280                                       country boyz  NaN
# 123281                                     the seed (2.0)  NaN
# 123282                                    10 million ways  NaN
# 123283                      ante up (robbin hoodz theory)  NaN
# 123284                                      whutcha want?  NaN
# 123285                                             switch  NaN
# 123286                                             r.i.p.  NaN
#
#                                                    lyrics language    genre  \
# 123267  money brooklyn money come danger rockin best b...      NaN  hip hop
# 123268  work niggas beef gonna spray pump street nigga...      NaN  hip hop
# 123269  rakim rakim knowledge try pay check nobry walt...      NaN  hip hop
# 123270  boom come baby boom come baby boom come baby c...      NaN  hip hop
# 123271  sink fuck spine second guess crime snort slug ...      NaN  hip hop
# 123272  doin turf punk message smokey smokey smokey mo...      NaN  hip hop
# 123273  life fill come fall away play bangin gonna ban...      NaN  hip hop
# 123274  fuckin cockroaches motherfuckin freebandz want...      NaN  hip hop
# 123275  nappy root gotta alright flyin dear leave lone...      NaN  hip hop
# 123276  eazye bitch galore bitch super duper group com...      NaN  hip hop
# 123277  internationally know hardcore real niggas inte...      NaN  hip hop
# 123278  spit shit damn nigga ridiculous nigga lose inc...      NaN  hip hop
# 123279  look comin straight slauson crazy motherfucker...      NaN  hip hop
# 123280  hook country boys country walk country talk br...      NaN  hip hop
# 123281  knock months finna know want neosoul hiphop wa...      NaN  hip hop
# 123282  cause fuck leave scar tick tock clock come kno...      NaN  hip hop
# 123283  minks things chain ring braclets yap fame come...      NaN  hip hop
# 123284  get ban get ban stick crack relax plan attack ...      NaN  hip hop
# 123285  check check yeah yeah hear thing call switch g...      NaN  hip hop
# 123286  remix killer alive remix thriller trap bitch s...      NaN  hip hop
#
#           date
# 123267  2019.0
# 123268  2019.0
# 123269  2019.0
# 123270  2019.0
# 123271  2019.0
# 123272  2019.0
# 123273  2019.0
# 123274  2019.0
# 123275  2019.0
# 123276  2019.0
# 123277  2019.0
# 123278  2019.0
# 123279  2019.0
# 123280  2019.0
# 123281  2019.0
# 123282  2019.0
# 123283  2019.0
# 123284  2019.0
# 123285  2019.0
# 123286  2019.0

# %%
big2_df[big2_df.duplicated(subset=['artist_name','song_name'])]
# Out:
#        original_csv    artist_name                song_name  \
# 1        genres_csv  10000-maniacs           More Than This
# 3        genres_csv  10000-maniacs        Because The Night
# 5        genres_csv  10000-maniacs           These Are Days
# 7        genres_csv  10000-maniacs          A Campfire Song
# 9        genres_csv  10000-maniacs  Everyday Is Like Sunday
# ...             ...            ...                      ...
# 94908    genres_csv          sambo  Smells Like Teen Spirit
# 94910    genres_csv          sambo                  Valerie
# 94912    genres_csv          sambo               Wake Me Up
# 97230   decades_tcc        blondie                    11:59
# 118994  decades_tcc          queen                      '39
#
#                                                link  \
# 1                /10000-maniacs/more-than-this.html
# 3             /10000-maniacs/because-the-night.html
# 5                /10000-maniacs/these-are-days.html
# 7               /10000-maniacs/a-campfire-song.html
# 9       /10000-maniacs/everyday-is-like-sunday.html
# ...                                             ...
# 94908           /sambo/smells-like-teen-spirit.html
# 94910                           /sambo/valerie.html
# 94912                        /sambo/wake-me-up.html
# 97230                                           NaN
# 118994                                          NaN
#
#                                                    lyrics language genre  \
# 1       I could feel at the time. There was no way of ...  ENGLISH   Pop
# 3       Take me now, baby, here as I am. Hold me close...  ENGLISH   Pop
# 5       These are. These are days you'll remember. Nev...  ENGLISH   Pop
# 7       A lie to say, "O my mountain has coal veins an...  ENGLISH   Pop
# 9       Trudging slowly over wet sand. Back to the ben...  ENGLISH   Pop
# ...                                                   ...      ...   ...
# 94908   (Chorus). Hello, hello,hello,how low. Hello,he...  ENGLISH  Rock
# 94910   Well sometimes I go out by myself. And I look ...  ENGLISH  Rock
# 94912   Feeling my way through the darkness. Guided by...  ENGLISH  Rock
# 97230   lean corner like candidate sidewalk social sci...      NaN   pop
# 118994  year assemble volunteer days land ship sail bl...      NaN  rock
#
#           date
# 1          NaN
# 3          NaN
# 5          NaN
# 7          NaN
# 9          NaN
# ...        ...
# 94908      NaN
# 94910      NaN
# 94912      NaN
# 97230   1978.0
# 118994  1975.0
#
# [7758 rows x 8 columns]

# %%
big2_df[big2_df.duplicated(subset=['lyrics'])]
# Out:
#       original_csv    artist_name                song_name  \
# 1       genres_csv  10000-maniacs           More Than This
# 3       genres_csv  10000-maniacs        Because The Night
# 5       genres_csv  10000-maniacs           These Are Days
# 7       genres_csv  10000-maniacs          A Campfire Song
# 9       genres_csv  10000-maniacs  Everyday Is Like Sunday
# ...            ...            ...                      ...
# 94904   genres_csv          sambo         Jingle Bell Rock
# 94906   genres_csv          sambo            Rock And Roll
# 94908   genres_csv          sambo  Smells Like Teen Spirit
# 94910   genres_csv          sambo                  Valerie
# 94912   genres_csv          sambo               Wake Me Up
#
#                                               link  \
# 1               /10000-maniacs/more-than-this.html
# 3            /10000-maniacs/because-the-night.html
# 5               /10000-maniacs/these-are-days.html
# 7              /10000-maniacs/a-campfire-song.html
# 9      /10000-maniacs/everyday-is-like-sunday.html
# ...                                            ...
# 94904                 /sambo/jingle-bell-rock.html
# 94906                    /sambo/rock-and-roll.html
# 94908          /sambo/smells-like-teen-spirit.html
# 94910                          /sambo/valerie.html
# 94912                       /sambo/wake-me-up.html
#
#                                                   lyrics language genre  date
# 1      I could feel at the time. There was no way of ...  ENGLISH   Pop   NaN
# 3      Take me now, baby, here as I am. Hold me close...  ENGLISH   Pop   NaN
# 5      These are. These are days you'll remember. Nev...  ENGLISH   Pop   NaN
# 7      A lie to say, "O my mountain has coal veins an...  ENGLISH   Pop   NaN
# 9      Trudging slowly over wet sand. Back to the ben...  ENGLISH   Pop   NaN
# ...                                                  ...      ...   ...   ...
# 94904  Jingle bell, jingle bell, jingle bell rock. Ji...  ENGLISH  Rock   NaN
# 94906  It's been a long time since I rock and rolled,...  ENGLISH  Rock   NaN
# 94908  (Chorus). Hello, hello,hello,how low. Hello,he...  ENGLISH  Rock   NaN
# 94910  Well sometimes I go out by myself. And I look ...  ENGLISH  Rock   NaN
# 94912  Feeling my way through the darkness. Guided by...  ENGLISH  Rock   NaN
#
# [8496 rows x 8 columns]

# %%
big2_df[big2_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [original_csv, artist_name, song_name, link, lyrics, language, genre, date]
# Index: []

# %%
big2_df.drop_duplicates(subset=['lyrics'], inplace = True)
big2_df.describe(include='all')
# Out:
#        original_csv    artist_name song_name  \
# count        114791         114791    114791
# unique            2           6441     90519
# top      genres_csv  elvis-presley     Intro
# freq          86419            747        50
# mean            NaN            NaN       NaN
# std             NaN            NaN       NaN
# min             NaN            NaN       NaN
# 25%             NaN            NaN       NaN
# 50%             NaN            NaN       NaN
# 75%             NaN            NaN       NaN
# max             NaN            NaN       NaN
#
#                                                   link  \
# count                                            86419
# unique                                           86419
# top     /joan-osborne/loves-in-need-of-love-today.html
# freq                                                 1
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#                                                    lyrics language   genre  \
# count                                              114791    86419  114791
# unique                                             114791        1      13
# top     Well ya know when you're young,. There's such ...  ENGLISH    Rock
# freq                                                    1    86419   47409
# mean                                                  NaN      NaN     NaN
# std                                                   NaN      NaN     NaN
# min                                                   NaN      NaN     NaN
# 25%                                                   NaN      NaN     NaN
# 50%                                                   NaN      NaN     NaN
# 75%                                                   NaN      NaN     NaN
# max                                                   NaN      NaN     NaN
#
#                 date
# count   28372.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     1990.236888
# std        18.487463
# min      1950.000000
# 25%      1975.000000
# 50%      1991.000000
# 75%      2007.000000
# max      2019.000000

# %%
big2_df.to_csv('big2_df.csv', index = False)
